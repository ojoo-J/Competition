# %%
import json
import pandas as pd
import numpy as np
import re
import networkx
from konlpy.tag import Komoran
import textrank
from textrank import KeywordSummarizer
from textrank import KeysentenceSummarizer
import tqdm

# %% [markdown]
# ## 데이터 불러오기

# %%
def load_jsonl(path):
    data=[]
    with open(path, 'r', encoding='utf-8') as reader:
        for line in reader:
            data.append(json.loads(line))
    return data

# %%
data_jsonl = load_jsonl("./extractive_test_v2.jsonl")
data_jsonl[0]
# Out:
# {'media': '당진시대',
#  'id': '500733466',
#  'article_original': ['▲ 석문간척지 임차법인협의회가 한국농어촌공사 당진지사 앞에 공공비축벼 320t을 쌓아두고 시위를 벌이고 있다.',
#   '석문간척지 임차법인협의회(이하 간척지협의회)가 농림축산식품부의 부당한 간척지 임대료 책정에 반발하며 지난달 30일 한국농어촌공사 당진지사 앞에 공공비축벼 320t을 쌓고 시위를 벌였다.',
#   '43개 영농조합법인이 소속된 간척지협의회는 이번 벼 야적 시위를 통해 현재 1kg당 2100원으로 책정된 임대료를 현재 쌀 판매가격인 1300원대로 인하할 것을 요구하고 있다.',
#   '이들은 지난 12월 7일 농림축산식품부에 탄원서를 제출했지만 “임대료 인하는 올해 이후에나 가능하다”고 통보받은 상황이다.',
#   '게다가 임차법인들의 계약기간이 올해 만료되기 때문에 임대료를 인하해도 지난 2년 동안의 손실 보상은 받을 수 없는 상황이다.',
#   '이에 간척지협의회는 계약기간을 2년 연장하고, 연장된 기간 동안 인하된 임대료를 적용해 지난 2년 간의 손실에 대해 보상할 것을 제안했다.',
#   '더불어 요구사항이 받아들여지지 않을 경우 벼 야적시위를 시작한 날짜인 지난해 12월 30일자로 임대료를 벼로 납부하겠다는 입장이다.',
#   '김재용 봉치영농조합법인 조합원은 “현재 한국농어촌공사의 답변을 기다리고 있다”며 “상황을 지켜본 뒤 추가적인 야적 시위 여부를 결정할 계획”이라고 말했다.',
#   '이어 “법을 만들고 집행할 때 현실성 있게 만들어야 한다”며 “농민이 정부를 믿을 수 있도록 조속히 해결책을 마련해주길 바란다”고 덧붙였다.']}

# %%
df = pd.DataFrame(data_jsonl)
df.head()
# Out:
#                                     article_original         id media
# 0  [▲ 석문간척지 임차법인협의회가 한국농어촌공사 당진지사 앞에 공공비축벼 320t을 ...  500733466  당진시대
# 1  [신 벌떼해장국이 손님들의 성원에 보답하고자 24시간 영업을 재개한다., 또한 이와...  500742482  당진시대
# 2  [1년 전과 비교해 당진지역 휘발유 가격은 72원, 경유 가격은 103원 상승했다....  500742484  당진시대
# 3  [어기구 국회의원이 천연가스의 안정적 수급을 위해 2020년 착공이 예정돼 있는 액...  504213810  당진시대
# 4  [당진시정책자문위원회가 유명무실하다는 비판이 지속적으로 제기되고 있다., 민선6기가...  505279620  당진시대

# %%
data = df.copy()

# %% [markdown]
# ## TextRank

# %%
sents = data['article_original'][0]
sents
# Out:
# ['▲ 석문간척지 임차법인협의회가 한국농어촌공사 당진지사 앞에 공공비축벼 320t을 쌓아두고 시위를 벌이고 있다.',
#  '석문간척지 임차법인협의회(이하 간척지협의회)가 농림축산식품부의 부당한 간척지 임대료 책정에 반발하며 지난달 30일 한국농어촌공사 당진지사 앞에 공공비축벼 320t을 쌓고 시위를 벌였다.',
#  '43개 영농조합법인이 소속된 간척지협의회는 이번 벼 야적 시위를 통해 현재 1kg당 2100원으로 책정된 임대료를 현재 쌀 판매가격인 1300원대로 인하할 것을 요구하고 있다.',
#  '이들은 지난 12월 7일 농림축산식품부에 탄원서를 제출했지만 “임대료 인하는 올해 이후에나 가능하다”고 통보받은 상황이다.',
#  '게다가 임차법인들의 계약기간이 올해 만료되기 때문에 임대료를 인하해도 지난 2년 동안의 손실 보상은 받을 수 없는 상황이다.',
#  '이에 간척지협의회는 계약기간을 2년 연장하고, 연장된 기간 동안 인하된 임대료를 적용해 지난 2년 간의 손실에 대해 보상할 것을 제안했다.',
#  '더불어 요구사항이 받아들여지지 않을 경우 벼 야적시위를 시작한 날짜인 지난해 12월 30일자로 임대료를 벼로 납부하겠다는 입장이다.',
#  '김재용 봉치영농조합법인 조합원은 “현재 한국농어촌공사의 답변을 기다리고 있다”며 “상황을 지켜본 뒤 추가적인 야적 시위 여부를 결정할 계획”이라고 말했다.',
#  '이어 “법을 만들고 집행할 때 현실성 있게 만들어야 한다”며 “농민이 정부를 믿을 수 있도록 조속히 해결책을 마련해주길 바란다”고 덧붙였다.']

# %% [markdown]
# #### 단어 뽑아서 열 생성

# %%
data['token_pos'] = ''

komoran = Komoran()

def komoran_tokenize(sent):
    words = komoran.pos(sent, join=True)
    words = [w for w in words if ('/NN' in w or '/XR' in w or '/VA' in w or '/VV' in w)]
    return words

for i in range(len(data)):
    data['token_pos'][i] = []
    for j in range(len(data['article_original'][i])):
        data['token_pos'][i].append(komoran_tokenize(data['article_original'][i][j]))
        
data['token_pos'][0]
# Out:
# [['석문/NNP',
#   '간척지/NNG',
#   '임차/NNG',
#   '법인/NNP',
#   '협의회/NNG',
#   '한국농어촌공사/NNP',
#   '당진/NNP',
#   '지사/NNP',
#   '앞/NNG',
#   '공공/NNG',
#   '비축/NNG',
#   '벼/NNG',
#   '쌓/VV',
#   '시위/NNG',
#   '벌이/VV'],
#  ['석문/NNP',
#   '간척지/NNG',
#   '임차/NNG',
#   '법인/NNP',
#   '협의회/NNG',
#   '이하/NNP',
#   '간척지/NNG',
#   '협의회/NNG',
#   '농림/NNP',
#   '축산/NNP',
#   '식품/NNG',
#   '부/NNG',
#   '부당/XR',
#   '간척지/NNG',
#   '임대료/NNG',
#   '책정/NNG',
#   '반발/NNG',
#   '지난달/NNG',
#   '일/NNB',
#   '한국농어촌공사/NNP',
#   '당진/NNP',
#   '지사/NNP',
#   '앞/NNG',
#   '공공/NNG',
#   '비축/NNG',
#   '벼/NNG',
#   '쌓/VV',
#   '시위/NNG',
#   '벌이/VV'],
#  ['개/NNB',
#   '영농/NNG',
#   '조합/NNP',
#   '법인/NNP',
#   '소속/NNG',
#   '간척지/NNG',
#   '협의회/NNG',
#   '이번/NNG',
#   '벼/NNG',
#   '야/NNG',
#   '시위/NNG',
#   '통하/VV',
#   '당/NNP',
#   '원/NNB',
#   '책정/NNG',
#   '임대료/NNG',
#   '쌀/NNG',
#   '판매/NNG',
#   '가격/NNG',
#   '원/NNB',
#   '인하/NNG',
#   '것/NNB',
#   '요구/NNG'],
#  ['지나/VV',
#   '12월 7일/NNP',
#   '농림/NNP',
#   '축산/NNP',
#   '식품/NNG',
#   '부/NNG',
#   '탄원서/NNG',
#   '제출/NNG',
#   '임대료/NNG',
#   '인하/VV',
#   '올해/NNG',
#   '이후/NNG',
#   '가능/XR',
#   '통보/NNG',
#   '받/VV',
#   '상황/NNG'],
#  ['임차/NNG',
#   '법인/NNG',
#   '계약/NNP',
#   '기간/NNP',
#   '올해/NNG',
#   '만료/NNG',
#   '때문/NNB',
#   '임대료/NNG',
#   '인하/NNG',
#   '지나/VV',
#   '년/NNB',
#   '동안/NNG',
#   '손실/NNP',
#   '보상/NNG',
#   '받/VV',
#   '수/NNB',
#   '없/VA',
#   '상황/NNG'],
#  ['간척지/NNG',
#   '협의회/NNG',
#   '계약/NNG',
#   '기간/NNG',
#   '년/NNB',
#   '연장/NNG',
#   '연장/NNG',
#   '기간/NNG',
#   '동안/NNG',
#   '인하/NNG',
#   '임대료/NNG',
#   '적용/NNG',
#   '지나/VV',
#   '년/NNB',
#   '간/NNB',
#   '손실/NNG',
#   '대하/VV',
#   '보상/NNG',
#   '것/NNB',
#   '제안/NNG'],
#  ['더불/VV',
#   '요구사항/NNP',
#   '받아들이/VV',
#   '경우/NNG',
#   '벼/NNG',
#   '야/NNG',
#   '시위/NNG',
#   '시작/NNG',
#   '날짜/NNG',
#   '지난해/NNG',
#   '12월 30일/NNP',
#   '자로/NNP',
#   '임대료/NNG',
#   '벼/NNG',
#   '납부/NNG',
#   '입장/NNG'],
#  ['김재용/NNP',
#   '봉치/NNG',
#   '영농/NNG',
#   '조합/NNP',
#   '법인/NNP',
#   '조합원/NNG',
#   '한국농어촌공사/NNP',
#   '답변/NNG',
#   '기다리/VV',
#   '있다/NNP',
#   '상황/NNG',
#   '지켜보/VV',
#   '뒤/NNG',
#   '추가/NNG',
#   '야/NNG',
#   '시위/NNP',
#   '여부/NNG',
#   '결정/NNG',
#   '계획/NNG',
#   '말/NNG'],
#  ['법/NNG',
#   '만들/VV',
#   '집행/NNG',
#   '때/NNG',
#   '현실/NNG',
#   '있/VV',
#   '만들/VV',
#   '하/VV',
#   '농민/NNG',
#   '정부/NNG',
#   '믿/VV',
#   '수/NNB',
#   '있/VV',
#   '해결책/NNG',
#   '마련/NNG',
#   '바라/VV',
#   '덧붙이/VV']]

# %%
def pos_to_string(list_):
    
    i_list=[]
    
    for i in range(len(list_)):
        
        j_str = ''
        
        for j in range(len(list_[i])):
            
            j_str = j_str + str(list_[i][j]) + ' '
        
        i_list.append(j_str)
    
    return i_list

# %%
data['token_str'] = data['token_pos'].map(pos_to_string)
data['token_str'][0]
# Out:
# ['석문/NNP 간척지/NNG 임차/NNG 법인/NNP 협의회/NNG 한국농어촌공사/NNP 당진/NNP 지사/NNP 앞/NNG 공공/NNG 비축/NNG 벼/NNG 쌓/VV 시위/NNG 벌이/VV ',
#  '석문/NNP 간척지/NNG 임차/NNG 법인/NNP 협의회/NNG 이하/NNP 간척지/NNG 협의회/NNG 농림/NNP 축산/NNP 식품/NNG 부/NNG 부당/XR 간척지/NNG 임대료/NNG 책정/NNG 반발/NNG 지난달/NNG 일/NNB 한국농어촌공사/NNP 당진/NNP 지사/NNP 앞/NNG 공공/NNG 비축/NNG 벼/NNG 쌓/VV 시위/NNG 벌이/VV ',
#  '개/NNB 영농/NNG 조합/NNP 법인/NNP 소속/NNG 간척지/NNG 협의회/NNG 이번/NNG 벼/NNG 야/NNG 시위/NNG 통하/VV 당/NNP 원/NNB 책정/NNG 임대료/NNG 쌀/NNG 판매/NNG 가격/NNG 원/NNB 인하/NNG 것/NNB 요구/NNG ',
#  '지나/VV 12월 7일/NNP 농림/NNP 축산/NNP 식품/NNG 부/NNG 탄원서/NNG 제출/NNG 임대료/NNG 인하/VV 올해/NNG 이후/NNG 가능/XR 통보/NNG 받/VV 상황/NNG ',
#  '임차/NNG 법인/NNG 계약/NNP 기간/NNP 올해/NNG 만료/NNG 때문/NNB 임대료/NNG 인하/NNG 지나/VV 년/NNB 동안/NNG 손실/NNP 보상/NNG 받/VV 수/NNB 없/VA 상황/NNG ',
#  '간척지/NNG 협의회/NNG 계약/NNG 기간/NNG 년/NNB 연장/NNG 연장/NNG 기간/NNG 동안/NNG 인하/NNG 임대료/NNG 적용/NNG 지나/VV 년/NNB 간/NNB 손실/NNG 대하/VV 보상/NNG 것/NNB 제안/NNG ',
#  '더불/VV 요구사항/NNP 받아들이/VV 경우/NNG 벼/NNG 야/NNG 시위/NNG 시작/NNG 날짜/NNG 지난해/NNG 12월 30일/NNP 자로/NNP 임대료/NNG 벼/NNG 납부/NNG 입장/NNG ',
#  '김재용/NNP 봉치/NNG 영농/NNG 조합/NNP 법인/NNP 조합원/NNG 한국농어촌공사/NNP 답변/NNG 기다리/VV 있다/NNP 상황/NNG 지켜보/VV 뒤/NNG 추가/NNG 야/NNG 시위/NNP 여부/NNG 결정/NNG 계획/NNG 말/NNG ',
#  '법/NNG 만들/VV 집행/NNG 때/NNG 현실/NNG 있/VV 만들/VV 하/VV 농민/NNG 정부/NNG 믿/VV 수/NNB 있/VV 해결책/NNG 마련/NNG 바라/VV 덧붙이/VV ']

# %%
data.head()
# Out:
#                                     article_original         id media  \
# 0  [▲ 석문간척지 임차법인협의회가 한국농어촌공사 당진지사 앞에 공공비축벼 320t을 ...  500733466  당진시대
# 1  [신 벌떼해장국이 손님들의 성원에 보답하고자 24시간 영업을 재개한다., 또한 이와...  500742482  당진시대
# 2  [1년 전과 비교해 당진지역 휘발유 가격은 72원, 경유 가격은 103원 상승했다....  500742484  당진시대
# 3  [어기구 국회의원이 천연가스의 안정적 수급을 위해 2020년 착공이 예정돼 있는 액...  504213810  당진시대
# 4  [당진시정책자문위원회가 유명무실하다는 비판이 지속적으로 제기되고 있다., 민선6기가...  505279620  당진시대
#
#                                            token_pos  \
# 0  [[석문/NNP, 간척지/NNG, 임차/NNG, 법인/NNP, 협의회/NNG, 한국...
# 1  [[신/NNG, 벌/NNG, 떼/NNG, 해장국/NNP, 손님/NNG, 성원/NNG...
# 2  [[년/NNB, 전과/NNP, 비교/NNG, 당진/NNP, 지역/NNP, 휘발유/N...
# 3  [[어기/VV, 국회의원/NNG, 천연가스/NNG, 안정/NNG, 수급/NNG, 위...
# 4  [[당진시/NNP, 정책/NNP, 자문/NNP, 위원회/NNP, 유명무실/NNG, ...
#
#                                            token_str
# 0  [석문/NNP 간척지/NNG 임차/NNG 법인/NNP 협의회/NNG 한국농어촌공사/...
# 1  [신/NNG 벌/NNG 떼/NNG 해장국/NNP 손님/NNG 성원/NNG 보답/NN...
# 2  [년/NNB 전과/NNP 비교/NNG 당진/NNP 지역/NNP 휘발유/NNP 가격/...
# 3  [어기/VV 국회의원/NNG 천연가스/NNG 안정/NNG 수급/NNG 위하/VV 년...
# 4  [당진시/NNP 정책/NNP 자문/NNP 위원회/NNP 유명무실/NNG 비판/NNG...

# %% [markdown]
# #### 핵심 단어 확인

# %%
from textrank import KeywordSummarizer

keyword_extractor = KeywordSummarizer(
    tokenize = komoran_tokenize,
    window = -1,
    verbose = False
)

keywords = keyword_extractor.summarize(sents, topk=30)
for word, rank in keywords:
    print('{} ({:.3})'.format(word, rank))
# Out:
# 간척지/NNG (2.63)
# 협의회/NNG (2.12)
# 임대료/NNG (1.89)
# 벼/NNG (1.46)
# 법인/NNP (1.41)
# 시위/NNG (1.37)
# 임차/NNG (1.25)
# 한국농어촌공사/NNP (1.1)
# 년/NNB (1.09)
# 인하/NNG (1.07)
# 책정/NNG (0.969)
# 벌이/VV (0.965)
# 석문/NNP (0.965)
# 당진/NNP (0.965)
# 지사/NNP (0.965)
# 앞/NNG (0.965)
# 공공/NNG (0.965)
# 비축/NNG (0.965)
# 쌓/VV (0.965)
# 지나/VV (0.964)
# 축산/NNP (0.864)
# 식품/NNG (0.864)
# 부/NNG (0.864)
# 농림/NNP (0.864)
# 연장/NNG (0.806)
# 기간/NNG (0.806)
# 것/NNB (0.786)
# 원/NNB (0.767)
# 상황/NNG (0.758)
# 동안/NNG (0.756)

# %% [markdown]
# #### 핵심 문장 뽑기

# %%
summarizer = KeysentenceSummarizer(
    tokenize = komoran_tokenize,
    min_sim = 0.5,
    verbose = True
    )

# %%
# sents 넣은 ver

def ext_keysentences_sents(sents, texts):
    
    ext_keysent = ''
    
    keysents = summarizer.summarize(sents) 
    
    for idx, rank, komoran_sent in keysents:
        ext_keysent = ext_keysent + str(texts[idx]) + '\n'
    
    return ext_keysent

# %%
# texts 넣은 ver

def ext_keysentences_texts(sents, texts):
    
    keysents = summarizer.summarize(texts) 
    
    ext_keysent = ''
    
    for idx, rank, komoran_sent in keysents:
        ext_keysent = ext_keysent + str(texts[idx]) + '\n'
    
    return ext_keysent

# %%
data['ext_keysent_sent']=''
data['ext_keysent_text']=''

for i in range(len(data)):
    data['ext_keysent_sent'][i] = ext_keysentences_sents(data['token_str'][i],data['article_original'][i])
    data['ext_keysent_text'][i] = ext_keysentences_texts(data['token_str'][i],data['article_original'][i])
# Out:
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 34 sents
# trained TextRank. n sentences = 34
# calculating textrank sentence similarity was done with 34 sents
# trained TextRank. n sentences = 34
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 39 sents
# trained TextRank. n sentences = 39
# calculating textrank sentence similarity was done with 39 sents
# trained TextRank. n sentences = 39
# calculating textrank sentence similarity was done with 31 sents
# trained TextRank. n sentences = 31
# calculating textrank sentence similarity was done with 31 sents
# trained TextRank. n sentences = 31
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 6 sents
# trained TextRank. n sentences = 6
# calculating textrank sentence similarity was done with 6 sents
# trained TextRank. n sentences = 6
# calculating textrank sentence similarity was done with 20 sents
# trained TextRank. n sentences = 20
# calculating textrank sentence similarity was done with 20 sents
# trained TextRank. n sentences = 20
# calculating textrank sentence similarity was done with 19 sents
# trained TextRank. n sentences = 19
# calculating textrank sentence similarity was done with 19 sents
# trained TextRank. n sentences = 19
# calculating textrank sentence similarity was done with 27 sents
# trained TextRank. n sentences = 27
# calculating textrank sentence similarity was done with 27 sents
# trained TextRank. n sentences = 27
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 16 sents
# trained TextRank. n sentences = 16
# calculating textrank sentence similarity was done with 16 sents
# trained TextRank. n sentences = 16
# calculating textrank sentence similarity was done with 23 sents
# trained TextRank. n sentences = 23
# calculating textrank sentence similarity was done with 23 sents
# trained TextRank. n sentences = 23
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 18 sents
# trained TextRank. n sentences = 18
# calculating textrank sentence similarity was done with 18 sents
# trained TextRank. n sentences = 18
# calculating textrank sentence similarity was done with 19 sents
# trained TextRank. n sentences = 19
# calculating textrank sentence similarity was done with 19 sents
# trained TextRank. n sentences = 19
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 31 sents
# trained TextRank. n sentences = 31
# calculating textrank sentence similarity was done with 31 sents
# trained TextRank. n sentences = 31
# calculating textrank sentence similarity was done with 33 sents
# trained TextRank. n sentences = 33
# calculating textrank sentence similarity was done with 33 sents
# trained TextRank. n sentences = 33
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 30 sents
# trained TextRank. n sentences = 30
# calculating textrank sentence similarity was done with 30 sents
# trained TextRank. n sentences = 30
# calculating textrank sentence similarity was done with 21 sents
# trained TextRank. n sentences = 21
# calculating textrank sentence similarity was done with 21 sents
# trained TextRank. n sentences = 21
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 24 sents
# trained TextRank. n sentences = 24
# calculating textrank sentence similarity was done with 24 sents
# trained TextRank. n sentences = 24
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 38 sents
# trained TextRank. n sentences = 38
# calculating textrank sentence similarity was done with 38 sents
# trained TextRank. n sentences = 38
# calculating textrank sentence similarity was done with 33 sents
# trained TextRank. n sentences = 33
# calculating textrank sentence similarity was done with 33 sents
# trained TextRank. n sentences = 33
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 24 sents
# trained TextRank. n sentences = 24
# calculating textrank sentence similarity was done with 24 sents
# trained TextRank. n sentences = 24
# calculating textrank sentence similarity was done with 25 sents
# trained TextRank. n sentences = 25
# calculating textrank sentence similarity was done with 25 sents
# trained TextRank. n sentences = 25
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 30 sents
# trained TextRank. n sentences = 30
# calculating textrank sentence similarity was done with 30 sents
# trained TextRank. n sentences = 30
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 22 sents
# trained TextRank. n sentences = 22
# calculating textrank sentence similarity was done with 22 sents
# trained TextRank. n sentences = 22
# calculating textrank sentence similarity was done with 18 sents
# trained TextRank. n sentences = 18
# calculating textrank sentence similarity was done with 18 sents
# trained TextRank. n sentences = 18
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 37 sents
# trained TextRank. n sentences = 37
# calculating textrank sentence similarity was done with 37 sents
# trained TextRank. n sentences = 37
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 19 sents
# trained TextRank. n sentences = 19
# calculating textrank sentence similarity was done with 19 sents
# trained TextRank. n sentences = 19
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 24 sents
# trained TextRank. n sentences = 24
# calculating textrank sentence similarity was done with 24 sents
# trained TextRank. n sentences = 24
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 28 sents
# trained TextRank. n sentences = 28
# calculating textrank sentence similarity was done with 28 sents
# trained TextRank. n sentences = 28
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 18 sents
# trained TextRank. n sentences = 18
# calculating textrank sentence similarity was done with 18 sents
# trained TextRank. n sentences = 18
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 27 sents
# trained TextRank. n sentences = 27
# calculating textrank sentence similarity was done with 27 sents
# trained TextRank. n sentences = 27
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 16 sents
# trained TextRank. n sentences = 16
# calculating textrank sentence similarity was done with 16 sents
# trained TextRank. n sentences = 16
# calculating textrank sentence similarity was done with 18 sents
# trained TextRank. n sentences = 18
# calculating textrank sentence similarity was done with 18 sents
# trained TextRank. n sentences = 18
# calculating textrank sentence similarity was done with 16 sents
# trained TextRank. n sentences = 16
# calculating textrank sentence similarity was done with 16 sents
# trained TextRank. n sentences = 16
# calculating textrank sentence similarity was done with 40 sents
# trained TextRank. n sentences = 40
# calculating textrank sentence similarity was done with 40 sents
# trained TextRank. n sentences = 40
# calculating textrank sentence similarity was done with 28 sents
# trained TextRank. n sentences = 28
# calculating textrank sentence similarity was done with 28 sents
# trained TextRank. n sentences = 28
# calculating textrank sentence similarity was done with 30 sents
# trained TextRank. n sentences = 30
# calculating textrank sentence similarity was done with 30 sents
# trained TextRank. n sentences = 30
# calculating textrank sentence similarity was done with 23 sents
# trained TextRank. n sentences = 23
# calculating textrank sentence similarity was done with 23 sents
# trained TextRank. n sentences = 23
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 24 sents
# trained TextRank. n sentences = 24
# calculating textrank sentence similarity was done with 24 sents
# trained TextRank. n sentences = 24
# calculating textrank sentence similarity was done with 24 sents
# trained TextRank. n sentences = 24
# calculating textrank sentence similarity was done with 24 sents
# trained TextRank. n sentences = 24
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 22 sents
# trained TextRank. n sentences = 22
# calculating textrank sentence similarity was done with 22 sents
# trained TextRank. n sentences = 22
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 25 sents
# trained TextRank. n sentences = 25
# calculating textrank sentence similarity was done with 25 sents
# trained TextRank. n sentences = 25
# calculating textrank sentence similarity was done with 23 sents
# trained TextRank. n sentences = 23
# calculating textrank sentence similarity was done with 23 sents
# trained TextRank. n sentences = 23
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 30 sents
# trained TextRank. n sentences = 30
# calculating textrank sentence similarity was done with 30 sents
# trained TextRank. n sentences = 30
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 31 sents
# trained TextRank. n sentences = 31
# calculating textrank sentence similarity was done with 31 sents
# trained TextRank. n sentences = 31
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 20 sents
# trained TextRank. n sentences = 20
# calculating textrank sentence similarity was done with 20 sents
# trained TextRank. n sentences = 20
# calculating textrank sentence similarity was done with 19 sents
# trained TextRank. n sentences = 19
# calculating textrank sentence similarity was done with 19 sents
# trained TextRank. n sentences = 19
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 21 sents
# trained TextRank. n sentences = 21
# calculating textrank sentence similarity was done with 21 sents
# trained TextRank. n sentences = 21
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 22 sents
# trained TextRank. n sentences = 22
# calculating textrank sentence similarity was done with 22 sents
# trained TextRank. n sentences = 22
# calculating textrank sentence similarity was done with 44 sents
# trained TextRank. n sentences = 44
# calculating textrank sentence similarity was done with 44 sents
# trained TextRank. n sentences = 44
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 21 sents
# trained TextRank. n sentences = 21
# calculating textrank sentence similarity was done with 21 sents
# trained TextRank. n sentences = 21
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 18 sents
# trained TextRank. n sentences = 18
# calculating textrank sentence similarity was done with 18 sents
# trained TextRank. n sentences = 18
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 28 sents
# trained TextRank. n sentences = 28
# calculating textrank sentence similarity was done with 28 sents
# trained TextRank. n sentences = 28
# calculating textrank sentence similarity was done with 35 sents
# trained TextRank. n sentences = 35
# calculating textrank sentence similarity was done with 35 sents
# trained TextRank. n sentences = 35
# calculating textrank sentence similarity was done with 35 sents
# trained TextRank. n sentences = 35
# calculating textrank sentence similarity was done with 35 sents
# trained TextRank. n sentences = 35
# calculating textrank sentence similarity was done with 6 sents
# trained TextRank. n sentences = 6
# calculating textrank sentence similarity was done with 6 sents
# trained TextRank. n sentences = 6
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 25 sents
# trained TextRank. n sentences = 25
# calculating textrank sentence similarity was done with 25 sents
# trained TextRank. n sentences = 25
# calculating textrank sentence similarity was done with 36 sents
# trained TextRank. n sentences = 36
# calculating textrank sentence similarity was done with 36 sents
# trained TextRank. n sentences = 36
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 18 sents
# trained TextRank. n sentences = 18
# calculating textrank sentence similarity was done with 18 sents
# trained TextRank. n sentences = 18
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 30 sents
# trained TextRank. n sentences = 30
# calculating textrank sentence similarity was done with 30 sents
# trained TextRank. n sentences = 30
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 37 sents
# trained TextRank. n sentences = 37
# calculating textrank sentence similarity was done with 37 sents
# trained TextRank. n sentences = 37
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 18 sents
# trained TextRank. n sentences = 18
# calculating textrank sentence similarity was done with 18 sents
# trained TextRank. n sentences = 18
# calculating textrank sentence similarity was done with 21 sents
# trained TextRank. n sentences = 21
# calculating textrank sentence similarity was done with 21 sents
# trained TextRank. n sentences = 21
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 33 sents
# trained TextRank. n sentences = 33
# calculating textrank sentence similarity was done with 33 sents
# trained TextRank. n sentences = 33
# calculating textrank sentence similarity was done with 16 sents
# trained TextRank. n sentences = 16
# calculating textrank sentence similarity was done with 16 sents
# trained TextRank. n sentences = 16
# calculating textrank sentence similarity was done with 18 sents
# trained TextRank. n sentences = 18
# calculating textrank sentence similarity was done with 18 sents
# trained TextRank. n sentences = 18
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 35 sents
# trained TextRank. n sentences = 35
# calculating textrank sentence similarity was done with 35 sents
# trained TextRank. n sentences = 35
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 30 sents
# trained TextRank. n sentences = 30
# calculating textrank sentence similarity was done with 30 sents
# trained TextRank. n sentences = 30
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 30 sents
# trained TextRank. n sentences = 30
# calculating textrank sentence similarity was done with 30 sents
# trained TextRank. n sentences = 30
# calculating textrank sentence similarity was done with 19 sents
# trained TextRank. n sentences = 19
# calculating textrank sentence similarity was done with 19 sents
# trained TextRank. n sentences = 19
# calculating textrank sentence similarity was done with 19 sents
# trained TextRank. n sentences = 19
# calculating textrank sentence similarity was done with 19 sents
# trained TextRank. n sentences = 19
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 29 sents
# trained TextRank. n sentences = 29
# calculating textrank sentence similarity was done with 29 sents
# trained TextRank. n sentences = 29
# calculating textrank sentence similarity was done with 33 sents
# trained TextRank. n sentences = 33
# calculating textrank sentence similarity was done with 33 sents
# trained TextRank. n sentences = 33
# calculating textrank sentence similarity was done with 21 sents
# trained TextRank. n sentences = 21
# calculating textrank sentence similarity was done with 21 sents
# trained TextRank. n sentences = 21
# calculating textrank sentence similarity was done with 33 sents
# trained TextRank. n sentences = 33
# calculating textrank sentence similarity was done with 33 sents
# trained TextRank. n sentences = 33
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 6 sents
# trained TextRank. n sentences = 6
# calculating textrank sentence similarity was done with 6 sents
# trained TextRank. n sentences = 6
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 47 sents
# trained TextRank. n sentences = 47
# calculating textrank sentence similarity was done with 47 sents
# trained TextRank. n sentences = 47
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 6 sents
# trained TextRank. n sentences = 6
# calculating textrank sentence similarity was done with 6 sents
# trained TextRank. n sentences = 6
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 16 sents
# trained TextRank. n sentences = 16
# calculating textrank sentence similarity was done with 16 sents
# trained TextRank. n sentences = 16
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 42 sents
# trained TextRank. n sentences = 42
# calculating textrank sentence similarity was done with 42 sents
# trained TextRank. n sentences = 42
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 27 sents
# trained TextRank. n sentences = 27
# calculating textrank sentence similarity was done with 27 sents
# trained TextRank. n sentences = 27
# calculating textrank sentence similarity was done with 5 sents
# trained TextRank. n sentences = 5
# calculating textrank sentence similarity was done with 5 sents
# trained TextRank. n sentences = 5
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 19 sents
# trained TextRank. n sentences = 19
# calculating textrank sentence similarity was done with 19 sents
# trained TextRank. n sentences = 19
# calculating textrank sentence similarity was done with 20 sents
# trained TextRank. n sentences = 20
# calculating textrank sentence similarity was done with 20 sents
# trained TextRank. n sentences = 20
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 22 sents
# trained TextRank. n sentences = 22
# calculating textrank sentence similarity was done with 22 sents
# trained TextRank. n sentences = 22
# calculating textrank sentence similarity was done with 24 sents
# trained TextRank. n sentences = 24
# calculating textrank sentence similarity was done with 24 sents
# trained TextRank. n sentences = 24
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 16 sents
# trained TextRank. n sentences = 16
# calculating textrank sentence similarity was done with 16 sents
# trained TextRank. n sentences = 16
# calculating textrank sentence similarity was done with 6 sents
# trained TextRank. n sentences = 6
# calculating textrank sentence similarity was done with 6 sents
# trained TextRank. n sentences = 6
# calculating textrank sentence similarity was done with 6 sents
# trained TextRank. n sentences = 6
# calculating textrank sentence similarity was done with 6 sents
# trained TextRank. n sentences = 6
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 36 sents
# trained TextRank. n sentences = 36
# calculating textrank sentence similarity was done with 36 sents
# trained TextRank. n sentences = 36
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 19 sents
# trained TextRank. n sentences = 19
# calculating textrank sentence similarity was done with 19 sents
# trained TextRank. n sentences = 19
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 20 sents
# trained TextRank. n sentences = 20
# calculating textrank sentence similarity was done with 20 sents
# trained TextRank. n sentences = 20
# calculating textrank sentence similarity was done with 32 sents
# trained TextRank. n sentences = 32
# calculating textrank sentence similarity was done with 32 sents
# trained TextRank. n sentences = 32
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# ...
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 22 sents
# trained TextRank. n sentences = 22
# calculating textrank sentence similarity was done with 22 sents
# trained TextRank. n sentences = 22
# calculating textrank sentence similarity was done with 21 sents
# trained TextRank. n sentences = 21
# calculating textrank sentence similarity was done with 21 sents
# trained TextRank. n sentences = 21
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 25 sents
# trained TextRank. n sentences = 25
# calculating textrank sentence similarity was done with 25 sents
# trained TextRank. n sentences = 25
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 20 sents
# trained TextRank. n sentences = 20
# calculating textrank sentence similarity was done with 20 sents
# trained TextRank. n sentences = 20
# calculating textrank sentence similarity was done with 19 sents
# trained TextRank. n sentences = 19
# calculating textrank sentence similarity was done with 19 sents
# trained TextRank. n sentences = 19
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 25 sents
# trained TextRank. n sentences = 25
# calculating textrank sentence similarity was done with 25 sents
# trained TextRank. n sentences = 25
# calculating textrank sentence similarity was done with 25 sents
# trained TextRank. n sentences = 25
# calculating textrank sentence similarity was done with 25 sents
# trained TextRank. n sentences = 25
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 20 sents
# trained TextRank. n sentences = 20
# calculating textrank sentence similarity was done with 20 sents
# trained TextRank. n sentences = 20
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 22 sents
# trained TextRank. n sentences = 22
# calculating textrank sentence similarity was done with 22 sents
# trained TextRank. n sentences = 22
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 21 sents
# trained TextRank. n sentences = 21
# calculating textrank sentence similarity was done with 21 sents
# trained TextRank. n sentences = 21
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 20 sents
# trained TextRank. n sentences = 20
# calculating textrank sentence similarity was done with 20 sents
# trained TextRank. n sentences = 20
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 21 sents
# trained TextRank. n sentences = 21
# calculating textrank sentence similarity was done with 21 sents
# trained TextRank. n sentences = 21
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 5 sents
# trained TextRank. n sentences = 5
# calculating textrank sentence similarity was done with 5 sents
# trained TextRank. n sentences = 5
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 26 sents
# trained TextRank. n sentences = 26
# calculating textrank sentence similarity was done with 26 sents
# trained TextRank. n sentences = 26
# calculating textrank sentence similarity was done with 20 sents
# trained TextRank. n sentences = 20
# calculating textrank sentence similarity was done with 20 sents
# trained TextRank. n sentences = 20
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 17 sents
# trained TextRank. n sentences = 17
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 8 sents
# trained TextRank. n sentences = 8
# calculating textrank sentence similarity was done with 27 sents
# trained TextRank. n sentences = 27
# calculating textrank sentence similarity was done with 27 sents
# trained TextRank. n sentences = 27
# calculating textrank sentence similarity was done with 18 sents
# trained TextRank. n sentences = 18
# calculating textrank sentence similarity was done with 18 sents
# trained TextRank. n sentences = 18
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 7 sents
# trained TextRank. n sentences = 7
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 11 sents
# trained TextRank. n sentences = 11
# calculating textrank sentence similarity was done with 27 sents
# trained TextRank. n sentences = 27
# calculating textrank sentence similarity was done with 27 sents
# trained TextRank. n sentences = 27
# calculating textrank sentence similarity was done with 23 sents
# trained TextRank. n sentences = 23
# calculating textrank sentence similarity was done with 23 sents
# trained TextRank. n sentences = 23
# calculating textrank sentence similarity was done with 24 sents
# trained TextRank. n sentences = 24
# calculating textrank sentence similarity was done with 24 sents
# trained TextRank. n sentences = 24
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 13 sents
# trained TextRank. n sentences = 13
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 15 sents
# trained TextRank. n sentences = 15
# calculating textrank sentence similarity was done with 6 sents
# trained TextRank. n sentences = 6
# calculating textrank sentence similarity was done with 6 sents
# trained TextRank. n sentences = 6
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 14 sents
# trained TextRank. n sentences = 14
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 12 sents
# trained TextRank. n sentences = 12
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 10 sents
# trained TextRank. n sentences = 10
# calculating textrank sentence similarity was done with 16 sents
# trained TextRank. n sentences = 16
# calculating textrank sentence similarity was done with 16 sents
# trained TextRank. n sentences = 16
# calculating textrank sentence similarity was done with 33 sents
# trained TextRank. n sentences = 33
# calculating textrank sentence similarity was done with 33 sents
# trained TextRank. n sentences = 33
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9
# calculating textrank sentence similarity was done with 9 sents
# trained TextRank. n sentences = 9

# %%
data['ext_keysent_sent'][1]
# Out:
# '앞으로도 변함이 없이 맛있는 음식을 제공하는 벌떼해장국이 되겠습니다.”\n또 대파와 청양고추를 넣어 매콤한 맛을 내면 한 그릇에도 든든한 뼈해장국이 완성된다.\n벌떼해장국의 주 메뉴는 뼈해장국과 감자탕이다.\n굴김치해장국에는 직접 담근 묵은지를 사용해 국물 맛이 시원하다.\n남기순 대표는 “잊지 않고 꾸준히 찾아 주신 손님들의 감사에 보답하고자 24시 영업을 재개하고 작은 이벤트를 마련했다”고 말했다.\n또한 벌떼해장국의 추천 메뉴는 콩나물황태해장국이다.\n술을 좋아해 자주 가던 해장국집에서 마침 이 대표에게 가게를 운영해 볼 생각이 없느냐고 제안했다.\n이미 입소문 난 메뉴로 뼈해장국 수준의 인기를 보인다고.\n감자탕에는 생감자와 콩나물이 더해져 우러날수록 국물이 시원하다.\n이 기간 동안 야간(저녁 11시~오전 7시)에 찾는 손님들을 위해 뼈해장국은 2000원, 감자탕은 5000원 할인된 가격으로 제공한다.\n하지만 갓 돌 지난 아들을 키우고 있었던 아내 남 대표는 그 당시 완강하게 음식점 운영을 반대했다.\nIMF 당시 남편 이복유 대표가 운영하던 대형부품납품업체가 어려워지며 문을 닫게 됐다.\n황태 단가가 높음에도 벌떼해장국에서는 저렴한 가격으로 손님들에게 제공하고 있다.\n집 부엌에도 잘 안 가던 이 대표가 처음인 식당을 운영하기란 쉬운 일이 아니었다.\n신 벌떼해장국이 손님들의 성원에 보답하고자 24시간 영업을 재개한다.\n돼지 목뼈만을 사용해 부드러운 살코기가 뼈에 가득 붙어 있다.\n■위치 : 당진시 무수동 7길 123 (하늘채코오롱아파트 정문 앞) ■문의 : 041-355-3282\n그래도 손님들이 ‘아무리 도망가도 찾아오겠다’고 말씀하실 정도로 많은 사랑을 주세요.\n남편 이 대표는 식당 운영의 어려움으로 결국 ‘식당 주변 200m 아내 접근 금지’를 내걸고 식당 운영을 시작했다.\n■메뉴 :뼈해장국 7000원, 뼈다귀감자탕 大3만 7000원, 中3만 2000원, 小2만 7000원, 콩나물황태해장국 6000원, 굴김치해장국 7000원, 해물뼈다귀전골 7만 5000원\n아내 남 씨는 남편이 걱정돼 아들을 업고 식당을 찾았고 파 손질하고 김치 한 번 담다가 어느덧 15년의 세월이 흘렀다.\n미리 조리해 놓는 방식이 아닌 주문 즉시 조리되기 때문에 콩나물의 아삭함이 살아있다.\n우릴 때는 무와 양파, 양파 껍질 및 대파 뿌리 등이 들어가 잡냄새가 없으며 이밖에도 국내산 마늘과 생강 등을 넣어 조미료 없이 감칠맛이 난다.\n지금은 단체 회식까지도 가능한 벌떼해장국이지만 처음 시작하던 15년 전에는 겨우 5평 남짓한 크기였다.\n한편 겨울철 특별메뉴로 굴김치해장국이 마련돼 있다.\n여기에 통영에서 공수한 신선한 굴과 생콩나물이 들어간다.\n황태는 고소한 맛을 위해 들기름에 볶아 사용하며 역시 주문 즉시 만든다.\n또한 육수는 초벌로 삶은 뼈를 한 번 더 4시간 동안 푹 고아낸 것을 사용해 깊고 진한 맛이 특징이다.\n여기에 우거지와 깻잎, 팽이버섯 등을 넣어 푸짐함을 더한다.\n“15년 동안 5번 식당 위치를 이전했을 정도로 다사다난했어요.\n'

# %%
data['ext_keysent_text'][1]
# Out:
# '벌떼해장국의 주 메뉴는 뼈해장국과 감자탕이다.\n굴김치해장국에는 직접 담근 묵은지를 사용해 국물 맛이 시원하다.\n■메뉴 :뼈해장국 7000원, 뼈다귀감자탕 大3만 7000원, 中3만 2000원, 小2만 7000원, 콩나물황태해장국 6000원, 굴김치해장국 7000원, 해물뼈다귀전골 7만 5000원\n또한 육수는 초벌로 삶은 뼈를 한 번 더 4시간 동안 푹 고아낸 것을 사용해 깊고 진한 맛이 특징이다.\n또한 벌떼해장국의 추천 메뉴는 콩나물황태해장국이다.\n하지만 갓 돌 지난 아들을 키우고 있었던 아내 남 대표는 그 당시 완강하게 음식점 운영을 반대했다.\n황태 단가가 높음에도 벌떼해장국에서는 저렴한 가격으로 손님들에게 제공하고 있다.\n신 벌떼해장국이 손님들의 성원에 보답하고자 24시간 영업을 재개한다.\n또 대파와 청양고추를 넣어 매콤한 맛을 내면 한 그릇에도 든든한 뼈해장국이 완성된다.\n술을 좋아해 자주 가던 해장국집에서 마침 이 대표에게 가게를 운영해 볼 생각이 없느냐고 제안했다.\nIMF 당시 남편 이복유 대표가 운영하던 대형부품납품업체가 어려워지며 문을 닫게 됐다.\n앞으로도 변함이 없이 맛있는 음식을 제공하는 벌떼해장국이 되겠습니다.”\n또한 이와 함께 오는 12일부터 31일까지 특별 감사 이벤트를 실시할 예정이다.\n여기에 통영에서 공수한 신선한 굴과 생콩나물이 들어간다.\n미리 조리해 놓는 방식이 아닌 주문 즉시 조리되기 때문에 콩나물의 아삭함이 살아있다.\n그래도 손님들이 ‘아무리 도망가도 찾아오겠다’고 말씀하실 정도로 많은 사랑을 주세요.\n지금은 단체 회식까지도 가능한 벌떼해장국이지만 처음 시작하던 15년 전에는 겨우 5평 남짓한 크기였다.\n집 부엌에도 잘 안 가던 이 대표가 처음인 식당을 운영하기란 쉬운 일이 아니었다.\n이 기간 동안 야간(저녁 11시~오전 7시)에 찾는 손님들을 위해 뼈해장국은 2000원, 감자탕은 5000원 할인된 가격으로 제공한다.\n아내 남 씨는 남편이 걱정돼 아들을 업고 식당을 찾았고 파 손질하고 김치 한 번 담다가 어느덧 15년의 세월이 흘렀다.\n우릴 때는 무와 양파, 양파 껍질 및 대파 뿌리 등이 들어가 잡냄새가 없으며 이밖에도 국내산 마늘과 생강 등을 넣어 조미료 없이 감칠맛이 난다.\n이미 입소문 난 메뉴로 뼈해장국 수준의 인기를 보인다고.\n남편 이 대표는 식당 운영의 어려움으로 결국 ‘식당 주변 200m 아내 접근 금지’를 내걸고 식당 운영을 시작했다.\n“15년 동안 5번 식당 위치를 이전했을 정도로 다사다난했어요.\n여기에 우거지와 깻잎, 팽이버섯 등을 넣어 푸짐함을 더한다.\n황태는 고소한 맛을 위해 들기름에 볶아 사용하며 역시 주문 즉시 만든다.\n한편 겨울철 특별메뉴로 굴김치해장국이 마련돼 있다.\n남기순 대표는 “잊지 않고 꾸준히 찾아 주신 손님들의 감사에 보답하고자 24시 영업을 재개하고 작은 이벤트를 마련했다”고 말했다.\n돼지 목뼈만을 사용해 부드러운 살코기가 뼈에 가득 붙어 있다.\n감자탕에는 생감자와 콩나물이 더해져 우러날수록 국물이 시원하다.\n'

# %% [markdown]
# #### 제출 데이터 만들기

# %%
data['ext_keysent_sent_list']=''
data['ext_keysent_text_list']=''

for i in range(len(data)):
    data['ext_keysent_sent_list'][i] = str(data['ext_keysent_sent'][i]).split('\n')[:3]
    data['ext_keysent_text_list'][i] = str(data['ext_keysent_text'][i]).split('\n')[:3]

# %%
type(data['ext_keysent_text_list'][1])
# Out:
# list

# %%
for i in range(len(data)):
    data['ext_keysent_sent_list'][i] = data['ext_keysent_sent_list'][i][0] + "\n" + data['ext_keysent_sent_list'][i][1] + "\n" + data['ext_keysent_sent_list'][i][2]
    data['ext_keysent_text_list'][i] = data['ext_keysent_text_list'][i][0] + "\n" + data['ext_keysent_text_list'][i][1] + "\n" + data['ext_keysent_text_list'][i][2]

# %%
data['ext_keysent_sent_list'][1]
# Out:
# '앞으로도 변함이 없이 맛있는 음식을 제공하는 벌떼해장국이 되겠습니다.”\n또 대파와 청양고추를 넣어 매콤한 맛을 내면 한 그릇에도 든든한 뼈해장국이 완성된다.\n벌떼해장국의 주 메뉴는 뼈해장국과 감자탕이다.'

# %%
data.head()
# Out:
#                                     article_original         id media  \
# 0  [▲ 석문간척지 임차법인협의회가 한국농어촌공사 당진지사 앞에 공공비축벼 320t을 ...  500733466  당진시대
# 1  [신 벌떼해장국이 손님들의 성원에 보답하고자 24시간 영업을 재개한다., 또한 이와...  500742482  당진시대
# 2  [1년 전과 비교해 당진지역 휘발유 가격은 72원, 경유 가격은 103원 상승했다....  500742484  당진시대
# 3  [어기구 국회의원이 천연가스의 안정적 수급을 위해 2020년 착공이 예정돼 있는 액...  504213810  당진시대
# 4  [당진시정책자문위원회가 유명무실하다는 비판이 지속적으로 제기되고 있다., 민선6기가...  505279620  당진시대
#
#                                            token_pos  \
# 0  [[석문/NNP, 간척지/NNG, 임차/NNG, 법인/NNP, 협의회/NNG, 한국...
# 1  [[신/NNG, 벌/NNG, 떼/NNG, 해장국/NNP, 손님/NNG, 성원/NNG...
# 2  [[년/NNB, 전과/NNP, 비교/NNG, 당진/NNP, 지역/NNP, 휘발유/N...
# 3  [[어기/VV, 국회의원/NNG, 천연가스/NNG, 안정/NNG, 수급/NNG, 위...
# 4  [[당진시/NNP, 정책/NNP, 자문/NNP, 위원회/NNP, 유명무실/NNG, ...
#
#                                            token_str  \
# 0  [석문/NNP 간척지/NNG 임차/NNG 법인/NNP 협의회/NNG 한국농어촌공사/...
# 1  [신/NNG 벌/NNG 떼/NNG 해장국/NNP 손님/NNG 성원/NNG 보답/NN...
# 2  [년/NNB 전과/NNP 비교/NNG 당진/NNP 지역/NNP 휘발유/NNP 가격/...
# 3  [어기/VV 국회의원/NNG 천연가스/NNG 안정/NNG 수급/NNG 위하/VV 년...
# 4  [당진시/NNP 정책/NNP 자문/NNP 위원회/NNP 유명무실/NNG 비판/NNG...
#
#                                     ext_keysent_sent  \
# 0  석문간척지 임차법인협의회(이하 간척지협의회)가 농림축산식품부의 부당한 간척지 임대료...
# 1  앞으로도 변함이 없이 맛있는 음식을 제공하는 벌떼해장국이 되겠습니다.”\n또 대파와...
# 2  한편 송악읍 (주)송악훼미리주유소의 휘발유 가격은 1439원으로 가장 낮았으며, 신...
# 3  이에 대해 어기구 의원은 “제12차 장기 천연가스수급계획에는 제5기지를 2020년부...
# 4  정책자문위원으로 활동하고 있는 A씨는 “연 1회 전체회의를 진행하는데 회의시간이 짧...
#
#                                     ext_keysent_text  \
# 0  석문간척지 임차법인협의회(이하 간척지협의회)가 농림축산식품부의 부당한 간척지 임대료...
# 1  벌떼해장국의 주 메뉴는 뼈해장국과 감자탕이다.\n굴김치해장국에는 직접 담근 묵은지를...
# 2  한국석유공사가 운영하는 오피넷(www.opinet.co.kr)에 따르면 최근 송악읍...
# 3  이에 대해 어기구 의원은 “제12차 장기 천연가스수급계획에는 제5기지를 2020년부...
# 4  정책자문위원으로 활동하고 있는 A씨는 “연 1회 전체회의를 진행하는데 회의시간이 짧...
#
#                                ext_keysent_sent_list  \
# 0  석문간척지 임차법인협의회(이하 간척지협의회)가 농림축산식품부의 부당한 간척지 임대료...
# 1  앞으로도 변함이 없이 맛있는 음식을 제공하는 벌떼해장국이 되겠습니다.”\n또 대파와...
# 2  한편 송악읍 (주)송악훼미리주유소의 휘발유 가격은 1439원으로 가장 낮았으며, 신...
# 3  이에 대해 어기구 의원은 “제12차 장기 천연가스수급계획에는 제5기지를 2020년부...
# 4  정책자문위원으로 활동하고 있는 A씨는 “연 1회 전체회의를 진행하는데 회의시간이 짧...
#
#                                ext_keysent_text_list
# 0  석문간척지 임차법인협의회(이하 간척지협의회)가 농림축산식품부의 부당한 간척지 임대료...
# 1  벌떼해장국의 주 메뉴는 뼈해장국과 감자탕이다.\n굴김치해장국에는 직접 담근 묵은지를...
# 2  한국석유공사가 운영하는 오피넷(www.opinet.co.kr)에 따르면 최근 송악읍...
# 3  이에 대해 어기구 의원은 “제12차 장기 천연가스수급계획에는 제5기지를 2020년부...
# 4  정책자문위원으로 활동하고 있는 A씨는 “연 1회 전체회의를 진행하는데 회의시간이 짧...

# %% [markdown]
# #### 제출파일 생성

# %%
sub_data_sent = data[['id','ext_keysent_sent_list']]
sub_data_text = data[['id','ext_keysent_text_list']]

sub_data_sent.rename(columns={'ext_keysent_sent_list': 'summary'}, inplace=True)
sub_data_text.rename(columns={'ext_keysent_text_list': 'summary'}, inplace=True)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
sub_data_sent.head()
# Out:
#           id                                            summary
# 0  500733466  석문간척지 임차법인협의회(이하 간척지협의회)가 농림축산식품부의 부당한 간척지 임대료...
# 1  500742482  앞으로도 변함이 없이 맛있는 음식을 제공하는 벌떼해장국이 되겠습니다.”\n또 대파와...
# 2  500742484  한편 송악읍 (주)송악훼미리주유소의 휘발유 가격은 1439원으로 가장 낮았으며, 신...
# 3  504213810  이에 대해 어기구 의원은 “제12차 장기 천연가스수급계획에는 제5기지를 2020년부...
# 4  505279620  정책자문위원으로 활동하고 있는 A씨는 “연 1회 전체회의를 진행하는데 회의시간이 짧...

# %%
sub_data_sent.to_csv('TextRank_sent.csv', encoding='utf-8-sig', index=False)
sub_data_text.to_csv('TextRank_text.csv', encoding='utf-8-sig', index=False)
